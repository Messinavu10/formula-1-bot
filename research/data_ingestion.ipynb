# %%
import os
os.chdir("/Users/naveenkumar/Desktop/formula-1-bot")
# %pwd
# Out:
# '/Users/naveenkumar/Desktop/formula-1-bot'

# %%
import requests
import pandas as pd
import json
import time
import logging
from pathlib import Path
from typing import Dict, List, Any, Optional
from urllib.parse import urlencode
from dataclasses import dataclass

# %%
# Update Cell 3: Data classes
@dataclass
class DataIngestionConfig:
    """Configuration for data ingestion from OpenF1 API"""
    source_url: str = "https://api.openf1.org/v1"
    api_timeout: int = 30
    max_retries: int = 3
    batch_size: int = 1000
    target_meetings: List[Dict[str, str]] = None
    sessions_to_ingest: List[str] = None
    endpoints: List[str] = None
    
    def __post_init__(self):
        if self.target_meetings is None:
            self.target_meetings = [{"meeting_key": "latest"}]
        if self.sessions_to_ingest is None:
            self.sessions_to_ingest = [
                "Practice 1", "Practice 2", "Practice 3", 
                "Qualifying", "Sprint", "Race"
            ]
        if self.endpoints is None:
            self.endpoints = [
                "meetings", "sessions", "drivers", "laps", 
                "pit", "stints", "position", 
                "intervals", "race_control", 
                "weather"
            ]

# %%
@dataclass
class DatabaseConfig:
    """Configuration for database"""
    host: str = "localhost"
    port: int = 5432
    database: str = "f1_bot"
    user: str = "f1_user"
    password: str = "f1_password"
    
    @property
    def connection_string(self) -> str:
        return f"postgresql://{self.user}:{self.password}@{self.host}:{self.port}/{self.database}"

# %%
from src.formula_one.constants import *
from src.formula_one.utils.common import read_yaml, create_directories

# %%
# Update Cell 6: Configuration Manager
class ConfigurationManager:
    """Manages configuration loading from YAML files"""
    
    def __init__(self, config_file_path: str = "config/config.yaml"):
        self.config_file_path = Path(config_file_path)
        self.config = read_yaml(self.config_file_path)
    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        """Get data ingestion configuration"""
        config_data = self.config.get('data_ingestion', {})
        
        return DataIngestionConfig(
            # API configuration only
            source_url=config_data.get('api', {}).get('base_url', 'https://api.openf1.org/v1'),
            api_timeout=config_data.get('api', {}).get('timeout', 30),
            max_retries=config_data.get('api', {}).get('max_retries', 3),
            batch_size=config_data.get('api', {}).get('batch_size', 1000),
            target_meetings=config_data.get('target_meetings', [{"meeting_key": "1219"}]),
            sessions_to_ingest=config_data.get('sessions_to_ingest', [
                "Practice 1", "Practice 2", "Practice 3", "Qualifying", "Race"
            ]),
            endpoints=config_data.get('endpoints', [
                "meetings", "sessions", "drivers", "laps", "pit", "stints", 
                "position", "intervals", "team_radio", "race_control", "weather"
            ])
        )

# %%
# Cell 6: API Client
import time

class OpenF1APIClient:
    def __init__(self, config: DataIngestionConfig):
        self.config = config
        self.session = requests.Session()
        self.session.timeout = config.api_timeout
        self.logger = logging.getLogger(__name__)
        self.last_request_time = 0
        self.min_request_interval = 0.5  # 500ms between requests
    
    def _make_request(self, endpoint: str, params: Optional[Dict[str, Any]] = None) -> List[Dict[str, Any]]:
        """Make API request with retry logic and rate limiting"""
        # Rate limiting
        current_time = time.time()
        time_since_last = current_time - self.last_request_time
        if time_since_last < self.min_request_interval:
            time.sleep(self.min_request_interval - time_since_last)
        
        url = f"{self.config.source_url}/{endpoint}"
        
        if params:
            url += f"?{urlencode(params)}"
        
        for attempt in range(self.config.max_retries):
            try:
                self.logger.info(f"Making request to: {url}")
                response = self.session.get(url)
                self.last_request_time = time.time()
                
                response.raise_for_status()
                
                data = response.json()
                self.logger.info(f"Successfully retrieved {len(data)} records from {endpoint}")
                return data
                
            except requests.exceptions.RequestException as e:
                self.logger.warning(f"Attempt {attempt + 1} failed for {endpoint}: {e}")
                if attempt == self.config.max_retries - 1:
                    raise
                time.sleep(2 ** attempt)  # Exponential backoff
    
    def get_meetings(self, year: Optional[int] = None) -> List[Dict[str, Any]]:
        """Get meetings/race weekends"""
        params = {"year": year} if year else {}
        return self._make_request("meetings", params)
    
    def get_sessions(self, meeting_key: str) -> List[Dict[str, Any]]:
        """Get sessions for a specific meeting"""
        params = {"meeting_key": meeting_key}
        return self._make_request("sessions", params)
    
    def get_drivers(self, session_key: str) -> List[Dict[str, Any]]:
        """Get drivers for a specific session"""
        params = {"session_key": session_key}
        return self._make_request("drivers", params)
    
    def get_laps(self, session_key: str) -> List[Dict[str, Any]]:
        """Get lap data for a specific session"""
        params = {"session_key": session_key}
        return self._make_request("laps", params)
    
    # def get_car_data(self, session_key: str, driver_number: Optional[int] = None) -> List[Dict[str, Any]]:
    #     """Get car telemetry data"""
    #     params = {"session_key": session_key}
    #     if driver_number:
    #         params["driver_number"] = driver_number
    #     return self._make_request("car_data", params)
    
    def get_pit_stops(self, session_key: str) -> List[Dict[str, Any]]:
        """Get pit stop data"""
        params = {"session_key": session_key}
        return self._make_request("pit", params)
    
    def get_stints(self, session_key: str) -> List[Dict[str, Any]]:
        """Get stint data"""
        params = {"session_key": session_key}
        return self._make_request("stints", params)
    
    def get_positions(self, session_key: str) -> List[Dict[str, Any]]:
        """Get position data"""
        params = {"session_key": session_key}
        return self._make_request("position", params)
    
    def get_intervals(self, session_key: str) -> List[Dict[str, Any]]:
        """Get interval data"""
        params = {"session_key": session_key}
        return self._make_request("intervals", params)
    
    # def get_team_radio(self, session_key: str) -> List[Dict[str, Any]]:
    #     """Get team radio data"""
    #     params = {"session_key": session_key}
    #     return self._make_request("team_radio", params)
    
    def get_race_control(self, session_key: str) -> List[Dict[str, Any]]:
        """Get race control data"""
        params = {"session_key": session_key}
        return self._make_request("race_control", params)
    
    def get_weather(self, session_key: str) -> List[Dict[str, Any]]:
        """Get weather data"""
        params = {"session_key": session_key}
        return self._make_request("weather", params)

# %%
# Update the DataIngestion class methods
class DataIngestion:
    """Main data ingestion pipeline"""
    
    def __init__(self, data_ingestion_config: DataIngestionConfig, api_client: OpenF1APIClient):
        self.data_ingestion_config = data_ingestion_config
        self.api_client = api_client
        self.logger = logging.getLogger(__name__)
    
    # Add this method to your DataIngestion class (around line 150)
    def _fetch_endpoint_data(self, endpoint: str, session_key: str) -> List[Dict[str, Any]]:
        """Fetch data for a specific endpoint"""
        endpoint_methods = {
            "sessions": lambda: self.api_client.get_sessions(session_key),
            "drivers": lambda: self.api_client.get_drivers(session_key),
            "laps": lambda: self.api_client.get_laps(session_key),
            #"car_data": lambda: self._safe_get_car_data(session_key),  # Use safe method
            "pit": lambda: self.api_client.get_pit_stops(session_key),
            "stints": lambda: self.api_client.get_stints(session_key),
            "position": lambda: self.api_client.get_positions(session_key),
            "intervals": lambda: self.api_client.get_intervals(session_key),
            #"team_radio": lambda: self.api_client.get_team_radio(session_key),
            "race_control": lambda: self.api_client.get_race_control(session_key),
            "weather": lambda: self.api_client.get_weather(session_key)
        }
        
        if endpoint in endpoint_methods:
            return endpoint_methods[endpoint]()
        else:
            self.logger.warning(f"Unknown endpoint: {endpoint}")
            return []

    # def _safe_get_car_data(self, session_key: str) -> List[Dict[str, Any]]:
    #     """Safely get car data, return empty list if not available"""
    #     try:
    #         return self.api_client.get_car_data(session_key)
    #     except Exception as e:
    #         self.logger.warning(f"Car data not available for session {session_key}: {e}")
    #         return []
    
    def ingest_meeting_data(self, meeting_key: str) -> Dict[str, Any]:
        """Ingest all data for a specific meeting"""
        self.logger.info(f"Starting data ingestion for meeting: {meeting_key}")
        
        # Get meeting info
        meetings = self.api_client.get_meetings()
        meeting_info = next((m for m in meetings if str(m.get('meeting_key')) == meeting_key), None)
        
        if not meeting_info:
            self.logger.error(f"Meeting {meeting_key} not found")
            return {}
        
        # Get sessions for this meeting
        sessions = self.api_client.get_sessions(meeting_key)
        self.logger.info(f"Found {len(sessions)} sessions for meeting {meeting_key}")
        
        meeting_data = {
            "meeting_info": meeting_info,
            "sessions": {},
        }
        
        # Ingest data for each session
        for session in sessions:
            session_name = session.get('session_name', 'Unknown')
            session_key = session.get('session_key')
            
            if session_name not in self.data_ingestion_config.sessions_to_ingest:
                self.logger.info(f"Skipping session: {session_name}")
                continue
            
            self.logger.info(f"Ingesting data for session: {session_name}")
            session_data = self._ingest_session_data(session_key, session_name, meeting_key)
            
            # Add session data to meeting_data
            meeting_data["sessions"][session_name] = session_data
        
        return meeting_data
    
    def _ingest_session_data(self, session_key: str, session_name: str, meeting_key: str) -> Dict[str, Any]:
        """Ingest data for a specific session"""
        session_data = {}
        
        for endpoint in self.data_ingestion_config.endpoints:
            try:
                if endpoint == "meetings":
                    continue
                
                data = self._fetch_endpoint_data(endpoint, session_key)
                session_data[endpoint] = data
                
                # Remove file saving - data will go to database
                self.logger.info(f"Retrieved {len(data)} records from {endpoint} for session {session_key}")
                
            except Exception as e:
                self.logger.error(f"Error ingesting {endpoint} for session {session_key}: {e}")
                session_data[endpoint] = []
        
        return session_data
    
    # Remove _save_raw_data and _save_meeting_data methods - no longer needed
    
    def run_ingestion(self):
        """Run the complete data ingestion pipeline"""
        self.logger.info("Starting data ingestion pipeline")
        
        for meeting_config in self.config.target_meetings:
            meeting_key = meeting_config["meeting_key"]
            try:
                self.ingest_meeting_data(meeting_key)
            except Exception as e:
                self.logger.error(f"Error ingesting meeting {meeting_key}: {e}")
        
        self.logger.info("Data ingestion pipeline completed")

# %%
# Add this new cell with the complete DatabaseIngestion class
import psycopg2
from psycopg2.extras import RealDictCursor
import pandas as pd

class DatabaseIngestion:
    """Handles database operations for F1 data"""
    
    def __init__(self, data_config: DataIngestionConfig, db_config: DatabaseConfig, api_client: OpenF1APIClient):
        self.data_config = data_config
        self.db_config = db_config
        self.api_client = api_client  # Add this line
        self.logger = logging.getLogger(__name__)
    
    def connect_to_db(self):
        """Create database connection"""
        try:
            conn = psycopg2.connect(
                host=self.db_config.host,
                port=self.db_config.port,
                database=self.db_config.database,
                user=self.db_config.user,
                password=self.db_config.password
            )
            self.logger.info("Successfully connected to PostgreSQL database")
            return conn
        except Exception as e:
            self.logger.error(f"Failed to connect to database: {e}")
            raise
    
    # Update the create_tables method with optimized ML-focused schema
    def create_tables(self):
        """Create database tables optimized for ML models"""
        conn = self.connect_to_db()
        cursor = conn.cursor()
        
        # Drop existing tables to recreate with optimized schema
        cursor.execute("DROP TABLE IF EXISTS weather CASCADE")
        cursor.execute("DROP TABLE IF EXISTS race_control CASCADE")
        #cursor.execute("DROP TABLE IF EXISTS team_radio CASCADE")
        cursor.execute("DROP TABLE IF EXISTS intervals CASCADE")
        cursor.execute("DROP TABLE IF EXISTS stints CASCADE")
        cursor.execute("DROP TABLE IF EXISTS pit_stops CASCADE")
        cursor.execute("DROP TABLE IF EXISTS positions CASCADE")
        cursor.execute("DROP TABLE IF EXISTS laps CASCADE")
        cursor.execute("DROP TABLE IF EXISTS drivers CASCADE")
        cursor.execute("DROP TABLE IF EXISTS sessions CASCADE")
        cursor.execute("DROP TABLE IF EXISTS meetings CASCADE")
        
        # Core tables with essential fields only
        cursor.execute("""
            CREATE TABLE meetings (
                meeting_key INTEGER PRIMARY KEY,
                meeting_name VARCHAR(255),
                country_name VARCHAR(100),
                circuit_short_name VARCHAR(100),
                date_start TIMESTAMP,
                year INTEGER,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        cursor.execute("""
            CREATE TABLE sessions (
                session_key INTEGER PRIMARY KEY,
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                session_name VARCHAR(100),
                session_type VARCHAR(50),
                date_start TIMESTAMP,
                date_end TIMESTAMP,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        cursor.execute("""
            CREATE TABLE drivers (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                full_name VARCHAR(100),
                team_name VARCHAR(100),
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # ML-focused laps table
        cursor.execute("""
            CREATE TABLE laps (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                lap_number INTEGER,
                lap_duration FLOAT,
                duration_sector_1 FLOAT,
                duration_sector_2 FLOAT,
                duration_sector_3 FLOAT,
                is_pit_out_lap BOOLEAN,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # ML-focused pit stops
        cursor.execute("""
            CREATE TABLE pit_stops (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                lap_number INTEGER,
                pit_duration FLOAT,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # ML-focused stints
        cursor.execute("""
            CREATE TABLE stints (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                compound VARCHAR(20),
                lap_start INTEGER,
                lap_end INTEGER,
                tyre_age_at_start INTEGER,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # ML-focused positions
        cursor.execute("""
            CREATE TABLE positions (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                position INTEGER,
                date TIMESTAMP,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # ML-focused weather
        cursor.execute("""
            CREATE TABLE weather (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                air_temperature FLOAT,
                track_temperature FLOAT,
                humidity FLOAT,
                rainfall BOOLEAN,
                date TIMESTAMP,
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)

        cursor.execute("""
            CREATE TABLE intervals (
                id SERIAL PRIMARY KEY,
                session_key INTEGER REFERENCES sessions(session_key),
                meeting_key INTEGER REFERENCES meetings(meeting_key),
                driver_number INTEGER,
                gap_to_leader FLOAT,  -- Time gap to race leader in seconds
                interval FLOAT,       -- Time gap to car ahead in seconds
                date TIMESTAMP,       -- UTC date and time
                created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        conn.commit()
        cursor.close()
        conn.close()
        self.logger.info("Optimized database tables created successfully")
    
    def insert_meeting_data(self, meeting_data: Dict[str, Any]):
        """Insert meeting data into database with optimized schema"""
        conn = self.connect_to_db()
        cursor = conn.cursor()
        
        try:
            # Insert meeting info - OPTIMIZED FIELDS ONLY
            meeting_info = meeting_data["meeting_info"]
            cursor.execute("""
                INSERT INTO meetings (
                    meeting_key, meeting_name, country_name, 
                    circuit_short_name, date_start, year
                ) VALUES (%s, %s, %s, %s, %s, %s)
                ON CONFLICT (meeting_key) DO NOTHING
            """, (
                meeting_info.get('meeting_key'),
                meeting_info.get('meeting_name'),
                meeting_info.get('country_name'),
                meeting_info.get('circuit_short_name'),
                meeting_info.get('date_start'),
                meeting_info.get('year')
            ))
            
            # Get the original sessions list
            sessions_list = self.api_client.get_sessions(str(meeting_info.get('meeting_key')))
            
            # Insert sessions - OPTIMIZED FIELDS ONLY
            for session_name, session_data in meeting_data["sessions"].items():
                # Find the session info from the original sessions list
                session_info = next((s for s in sessions_list if s.get('session_name') == session_name), None)
                
                if session_info:
                    cursor.execute("""
                        INSERT INTO sessions (
                            session_key, meeting_key, session_name, session_type,
                            date_start, date_end
                        ) VALUES (%s, %s, %s, %s, %s, %s)
                        ON CONFLICT (session_key) DO NOTHING
                    """, (
                        session_info.get('session_key'),
                        meeting_info.get('meeting_key'),
                        session_info.get('session_name'),
                        session_info.get('session_type'),
                        session_info.get('date_start'),
                        session_info.get('date_end')
                    ))
                    
                    # Insert drivers for this session - OPTIMIZED FIELDS ONLY
                    if "drivers" in session_data and session_data["drivers"]:
                        for driver in session_data["drivers"]:
                            cursor.execute("""
                                INSERT INTO drivers (
                                    session_key, meeting_key, driver_number,
                                    full_name, team_name
                                ) VALUES (%s, %s, %s, %s, %s)
                                ON CONFLICT DO NOTHING
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                driver.get('driver_number'),
                                driver.get('full_name'),
                                driver.get('team_name')
                            ))
                    
                    # Insert laps for this session - OPTIMIZED FIELDS ONLY
                    if "laps" in session_data and session_data["laps"]:
                        for lap in session_data["laps"]:
                            cursor.execute("""
                                INSERT INTO laps (
                                    session_key, meeting_key, driver_number, lap_number,
                                    lap_duration, duration_sector_1, duration_sector_2, 
                                    duration_sector_3, is_pit_out_lap
                                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                lap.get('driver_number'),
                                lap.get('lap_number'),
                                lap.get('lap_duration'),
                                lap.get('duration_sector_1'),
                                lap.get('duration_sector_2'),
                                lap.get('duration_sector_3'),
                                lap.get('is_pit_out_lap')
                            ))
                    
                    # Insert pit stops for this session - OPTIMIZED FIELDS ONLY
                    if "pit" in session_data and session_data["pit"]:
                        for pit in session_data["pit"]:
                            cursor.execute("""
                                INSERT INTO pit_stops (
                                    session_key, meeting_key, driver_number, 
                                    lap_number, pit_duration
                                ) VALUES (%s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                pit.get('driver_number'),
                                pit.get('lap_number'),
                                pit.get('pit_duration')
                            ))
                    
                    # Insert stints for this session - OPTIMIZED FIELDS ONLY
                    if "stints" in session_data and session_data["stints"]:
                        for stint in session_data["stints"]:
                            cursor.execute("""
                                INSERT INTO stints (
                                    session_key, meeting_key, driver_number,
                                    compound, lap_start, lap_end, tyre_age_at_start
                                ) VALUES (%s, %s, %s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                stint.get('driver_number'),
                                stint.get('compound'),
                                stint.get('lap_start'),
                                stint.get('lap_end'),
                                stint.get('tyre_age_at_start')
                            ))
                    
                    # Insert positions for this session - OPTIMIZED FIELDS ONLY
                    if "position" in session_data and session_data["position"]:
                        for pos in session_data["position"]:
                            cursor.execute("""
                                INSERT INTO positions (
                                    session_key, meeting_key, driver_number, 
                                    position, date
                                ) VALUES (%s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                pos.get('driver_number'),
                                pos.get('position'),
                                pos.get('date')
                            ))
                    
                    # Insert weather for this session - OPTIMIZED FIELDS ONLY
                    if "weather" in session_data and session_data["weather"]:
                        for weather in session_data["weather"]:
                            cursor.execute("""
                                INSERT INTO weather (
                                    session_key, meeting_key, air_temperature,
                                    track_temperature, humidity, rainfall, date
                                ) VALUES (%s, %s, %s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                weather.get('air_temperature'),
                                weather.get('track_temperature'),
                                weather.get('humidity'),
                                bool(weather.get('rainfall', 0)),  # Convert int to bool
                                weather.get('date')
                            ))
                    
                    if "intervals" in session_data and session_data["intervals"]:
                        for interval in session_data["intervals"]:
                            cursor.execute("""
                                INSERT INTO intervals (
                                    session_key, meeting_key, driver_number, 
                                    gap_to_leader, interval, date
                                ) VALUES (%s, %s, %s, %s, %s, %s)
                            """, (
                                session_info.get('session_key'),
                                meeting_info.get('meeting_key'),
                                interval.get('driver_number'),
                                interval.get('gap_to_leader'),
                                interval.get('interval'),
                                interval.get('date')
                            ))
            
            # IMPORTANT: Explicitly commit the transaction
            conn.commit()
            self.logger.info(f"Successfully inserted meeting {meeting_info.get('meeting_key')} data with optimized schema")
            
        except Exception as e:
            conn.rollback()
            self.logger.error(f"Error inserting meeting data: {e}")
            raise
        finally:
            cursor.close()
            conn.close()

# %%
# Simple discovery - just run this cell
config_manager = ConfigurationManager()
data_ingestion_config = config_manager.get_data_ingestion_config()
api_client = OpenF1APIClient(data_ingestion_config)

# Get all meetings
meetings = api_client.get_meetings()

# Filter for 2025
meetings_2025 = [m for m in meetings if m.get('year') == 2025]
meetings_2025.sort(key=lambda x: x.get('date_start', ''))

print(f"Found {len(meetings_2025)} meetings in 2025:")
for meeting in meetings_2025:
    print(f"  - {meeting.get('meeting_name')} (Key: {meeting.get('meeting_key')})")
# Out:
# [2025-07-02 18:25:40,526: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2025-07-02 18:25:40,527: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:25:40,841: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# Found 12 meetings in 2025:
#   - Pre-Season Testing (Key: 1253)
#   - Australian Grand Prix (Key: 1254)
#   - Chinese Grand Prix (Key: 1255)
#   - Japanese Grand Prix (Key: 1256)
#   - Bahrain Grand Prix (Key: 1257)
#   - Saudi Arabian Grand Prix (Key: 1258)
#   - Miami Grand Prix (Key: 1259)
#   - Emilia Romagna Grand Prix (Key: 1260)
#   - Monaco Grand Prix (Key: 1261)
#   - Spanish Grand Prix (Key: 1262)
#   - Canadian Grand Prix (Key: 1263)
#   - Austrian Grand Prix (Key: 1264)

# %%
# Load configuration
config_manager = ConfigurationManager()
data_ingestion_config = config_manager.get_data_ingestion_config()
db_config = DatabaseConfig()

# Create API client and database ingestion
api_client = OpenF1APIClient(data_ingestion_config)
db_ingestion = DatabaseIngestion(data_ingestion_config, db_config, api_client)

# Create tables first
db_ingestion.create_tables()

# Discover available 2025 meetings
available_meetings = discover_2025_meetings()

# Ingest data for each meeting
for meeting in available_meetings:
    meeting_key = str(meeting.get('meeting_key'))
    meeting_name = meeting.get('meeting_name')
    
    print(f"\n=== Ingesting {meeting_name} (Key: {meeting_key}) ===")
    
    # Create data ingestion instance for this meeting
    data_ingestion = DataIngestion(data_ingestion_config, api_client)
    
    # Ingest data for this meeting
    meeting_data = data_ingestion.ingest_meeting_data(meeting_key)
    
    # Insert into database
    if meeting_data:
        db_ingestion.insert_meeting_data(meeting_data)
        print(f"✅ {meeting_name} data successfully ingested!")
    else:
        print(f"❌ Failed to ingest {meeting_name}")

print("\n🎉 All 2025 data ingestion completed!")
# Out:
# [2025-07-02 18:25:40,847: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2025-07-02 18:25:40,923: INFO: 1957311327: Successfully connected to PostgreSQL database]
# [2025-07-02 18:25:41,000: INFO: 1957311327: Optimized database tables created successfully]
# [2025-07-02 18:25:41,000: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:25:41,342: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# Found 12 meetings in 2025:
#   - Pre-Season Testing (Key: 1253)
#   - Australian Grand Prix (Key: 1254)
#   - Chinese Grand Prix (Key: 1255)
#   - Japanese Grand Prix (Key: 1256)
#   - Bahrain Grand Prix (Key: 1257)
#   - Saudi Arabian Grand Prix (Key: 1258)
#   - Miami Grand Prix (Key: 1259)
#   - Emilia Romagna Grand Prix (Key: 1260)
#   - Monaco Grand Prix (Key: 1261)
#   - Spanish Grand Prix (Key: 1262)
#   - Canadian Grand Prix (Key: 1263)
#   - Austrian Grand Prix (Key: 1264)
#
# === Ingesting Pre-Season Testing (Key: 1253) ===
# [2025-07-02 18:25:41,343: INFO: 1557249241: Starting data ingestion for meeting: 1253]
# [2025-07-02 18:25:41,343: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:25:41,683: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# [2025-07-02 18:25:42,187: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1253]
# [2025-07-02 18:25:42,369: INFO: 1829873344: Successfully retrieved 3 records from sessions]
# [2025-07-02 18:25:42,369: INFO: 1557249241: Found 3 sessions for meeting 1253]
# [2025-07-02 18:25:42,370: INFO: 1557249241: Skipping session: Day 1]
# [2025-07-02 18:25:42,370: INFO: 1557249241: Skipping session: Day 2]
# [2025-07-02 18:25:42,370: INFO: 1557249241: Skipping session: Day 3]
# [2025-07-02 18:25:42,375: INFO: 1957311327: Successfully connected to PostgreSQL database]
# [2025-07-02 18:25:42,874: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1253]
# [2025-07-02 18:25:43,071: INFO: 1829873344: Successfully retrieved 3 records from sessions]
# [2025-07-02 18:25:43,072: INFO: 1957311327: Successfully inserted meeting 1253 data with optimized schema]
# ✅ Pre-Season Testing data successfully ingested!
#
# === Ingesting Australian Grand Prix (Key: 1254) ===
# [2025-07-02 18:25:43,073: INFO: 1557249241: Starting data ingestion for meeting: 1254]
# [2025-07-02 18:25:43,573: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:25:43,786: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# [2025-07-02 18:25:44,291: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1254]
# [2025-07-02 18:25:44,482: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:25:44,482: INFO: 1557249241: Found 5 sessions for meeting 1254]
# [2025-07-02 18:25:44,483: INFO: 1557249241: Ingesting data for session: Practice 1]
# [2025-07-02 18:25:44,985: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9686]
# [2025-07-02 18:25:45,176: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:25:45,177: INFO: 1557249241: Retrieved 0 records from sessions for session 9686]
# [2025-07-02 18:25:45,678: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9686]
# [2025-07-02 18:25:45,903: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:25:45,904: INFO: 1557249241: Retrieved 20 records from drivers for session 9686]
# [2025-07-02 18:25:46,404: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9686]
# [2025-07-02 18:25:47,289: INFO: 1829873344: Successfully retrieved 420 records from laps]
# [2025-07-02 18:25:47,290: INFO: 1557249241: Retrieved 420 records from laps for session 9686]
# [2025-07-02 18:25:47,290: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:25:47,290: INFO: 1557249241: Retrieved 0 records from car_data for session 9686]
# [2025-07-02 18:25:47,793: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9686]
# [2025-07-02 18:25:48,039: INFO: 1829873344: Successfully retrieved 80 records from pit]
# [2025-07-02 18:25:48,040: INFO: 1557249241: Retrieved 80 records from pit for session 9686]
# [2025-07-02 18:25:48,544: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9686]
# [2025-07-02 18:25:48,798: INFO: 1829873344: Successfully retrieved 80 records from stints]
# [2025-07-02 18:25:48,800: INFO: 1557249241: Retrieved 80 records from stints for session 9686]
# [2025-07-02 18:25:49,302: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9686]
# [2025-07-02 18:25:49,725: INFO: 1829873344: Successfully retrieved 647 records from position]
# [2025-07-02 18:25:49,727: INFO: 1557249241: Retrieved 647 records from position for session 9686]
# [2025-07-02 18:25:50,227: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9686]
# [2025-07-02 18:25:50,426: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:25:50,428: INFO: 1557249241: Retrieved 0 records from intervals for session 9686]
# [2025-07-02 18:25:50,931: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9686]
# [2025-07-02 18:25:51,137: INFO: 1829873344: Successfully retrieved 0 records from team_radio]
# [2025-07-02 18:25:51,140: INFO: 1557249241: Retrieved 0 records from team_radio for session 9686]
# [2025-07-02 18:25:51,641: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9686]
# [2025-07-02 18:25:51,873: INFO: 1829873344: Successfully retrieved 29 records from race_control]
# [2025-07-02 18:25:51,874: INFO: 1557249241: Retrieved 29 records from race_control for session 9686]
# [2025-07-02 18:25:52,378: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9686]
# [2025-07-02 18:25:52,589: INFO: 1829873344: Successfully retrieved 81 records from weather]
# [2025-07-02 18:25:52,590: INFO: 1557249241: Retrieved 81 records from weather for session 9686]
# [2025-07-02 18:25:52,591: INFO: 1557249241: Ingesting data for session: Practice 2]
# [2025-07-02 18:25:53,094: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9687]
# [2025-07-02 18:25:53,288: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:25:53,290: INFO: 1557249241: Retrieved 0 records from sessions for session 9687]
# [2025-07-02 18:25:53,793: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9687]
# [2025-07-02 18:25:54,011: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:25:54,013: INFO: 1557249241: Retrieved 20 records from drivers for session 9687]
# [2025-07-02 18:25:54,516: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9687]
# [2025-07-02 18:25:55,616: INFO: 1829873344: Successfully retrieved 552 records from laps]
# [2025-07-02 18:25:55,616: INFO: 1557249241: Retrieved 552 records from laps for session 9687]
# [2025-07-02 18:25:55,616: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:25:55,617: INFO: 1557249241: Retrieved 0 records from car_data for session 9687]
# [2025-07-02 18:25:56,116: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9687]
# [2025-07-02 18:25:56,375: INFO: 1829873344: Successfully retrieved 83 records from pit]
# [2025-07-02 18:25:56,376: INFO: 1557249241: Retrieved 83 records from pit for session 9687]
# [2025-07-02 18:25:56,879: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9687]
# [2025-07-02 18:25:57,124: INFO: 1829873344: Successfully retrieved 83 records from stints]
# [2025-07-02 18:25:57,126: INFO: 1557249241: Retrieved 83 records from stints for session 9687]
# [2025-07-02 18:25:57,625: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9687]
# [2025-07-02 18:25:57,862: INFO: 1829873344: Successfully retrieved 486 records from position]
# [2025-07-02 18:25:57,863: INFO: 1557249241: Retrieved 486 records from position for session 9687]
# [2025-07-02 18:25:58,366: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9687]
# [2025-07-02 18:25:58,568: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:25:58,570: INFO: 1557249241: Retrieved 0 records from intervals for session 9687]
# [2025-07-02 18:25:59,071: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9687]
# [2025-07-02 18:25:59,279: INFO: 1829873344: Successfully retrieved 0 records from team_radio]
# [2025-07-02 18:25:59,281: INFO: 1557249241: Retrieved 0 records from team_radio for session 9687]
# [2025-07-02 18:25:59,780: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9687]
# [2025-07-02 18:25:59,999: INFO: 1829873344: Successfully retrieved 10 records from race_control]
# [2025-07-02 18:26:00,001: INFO: 1557249241: Retrieved 10 records from race_control for session 9687]
# [2025-07-02 18:26:00,501: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9687]
# [2025-07-02 18:26:00,758: INFO: 1829873344: Successfully retrieved 81 records from weather]
# [2025-07-02 18:26:00,758: INFO: 1557249241: Retrieved 81 records from weather for session 9687]
# [2025-07-02 18:26:00,759: INFO: 1557249241: Ingesting data for session: Practice 3]
# [2025-07-02 18:26:01,263: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9688]
# [2025-07-02 18:26:01,442: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:01,442: INFO: 1557249241: Retrieved 0 records from sessions for session 9688]
# [2025-07-02 18:26:01,947: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9688]
# [2025-07-02 18:26:02,146: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:02,146: INFO: 1557249241: Retrieved 20 records from drivers for session 9688]
# [2025-07-02 18:26:02,651: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9688]
# [2025-07-02 18:26:03,549: INFO: 1829873344: Successfully retrieved 351 records from laps]
# [2025-07-02 18:26:03,550: INFO: 1557249241: Retrieved 351 records from laps for session 9688]
# [2025-07-02 18:26:03,550: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:03,550: INFO: 1557249241: Retrieved 0 records from car_data for session 9688]
# [2025-07-02 18:26:04,052: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9688]
# [2025-07-02 18:26:04,260: INFO: 1829873344: Successfully retrieved 104 records from pit]
# [2025-07-02 18:26:04,261: INFO: 1557249241: Retrieved 104 records from pit for session 9688]
# [2025-07-02 18:26:04,764: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9688]
# [2025-07-02 18:26:05,011: INFO: 1829873344: Successfully retrieved 104 records from stints]
# [2025-07-02 18:26:05,012: INFO: 1557249241: Retrieved 104 records from stints for session 9688]
# [2025-07-02 18:26:05,516: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9688]
# [2025-07-02 18:26:06,037: INFO: 1829873344: Successfully retrieved 584 records from position]
# [2025-07-02 18:26:06,037: INFO: 1557249241: Retrieved 584 records from position for session 9688]
# [2025-07-02 18:26:06,541: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9688]
# [2025-07-02 18:26:06,737: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:26:06,738: INFO: 1557249241: Retrieved 0 records from intervals for session 9688]
# [2025-07-02 18:26:07,239: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9688]
# [2025-07-02 18:26:07,446: INFO: 1829873344: Successfully retrieved 3 records from team_radio]
# [2025-07-02 18:26:07,448: INFO: 1557249241: Retrieved 3 records from team_radio for session 9688]
# [2025-07-02 18:26:07,950: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9688]
# [2025-07-02 18:26:08,153: INFO: 1829873344: Successfully retrieved 14 records from race_control]
# [2025-07-02 18:26:08,155: INFO: 1557249241: Retrieved 14 records from race_control for session 9688]
# [2025-07-02 18:26:08,654: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9688]
# [2025-07-02 18:26:08,881: INFO: 1829873344: Successfully retrieved 78 records from weather]
# [2025-07-02 18:26:08,884: INFO: 1557249241: Retrieved 78 records from weather for session 9688]
# [2025-07-02 18:26:08,884: INFO: 1557249241: Ingesting data for session: Qualifying]
# [2025-07-02 18:26:09,386: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9689]
# [2025-07-02 18:26:09,584: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:09,586: INFO: 1557249241: Retrieved 0 records from sessions for session 9689]
# [2025-07-02 18:26:10,087: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9689]
# [2025-07-02 18:26:10,290: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:10,292: INFO: 1557249241: Retrieved 20 records from drivers for session 9689]
# [2025-07-02 18:26:10,795: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9689]
# [2025-07-02 18:26:11,489: INFO: 1829873344: Successfully retrieved 303 records from laps]
# [2025-07-02 18:26:11,490: INFO: 1557249241: Retrieved 303 records from laps for session 9689]
# [2025-07-02 18:26:11,490: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:11,490: INFO: 1557249241: Retrieved 0 records from car_data for session 9689]
# [2025-07-02 18:26:11,994: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9689]
# [2025-07-02 18:26:12,234: INFO: 1829873344: Successfully retrieved 101 records from pit]
# [2025-07-02 18:26:12,235: INFO: 1557249241: Retrieved 101 records from pit for session 9689]
# [2025-07-02 18:26:12,739: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9689]
# [2025-07-02 18:26:13,047: INFO: 1829873344: Successfully retrieved 101 records from stints]
# [2025-07-02 18:26:13,049: INFO: 1557249241: Retrieved 101 records from stints for session 9689]
# [2025-07-02 18:26:13,551: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9689]
# [2025-07-02 18:26:14,007: INFO: 1829873344: Successfully retrieved 1062 records from position]
# [2025-07-02 18:26:14,007: INFO: 1557249241: Retrieved 1062 records from position for session 9689]
# [2025-07-02 18:26:14,511: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9689]
# [2025-07-02 18:26:14,696: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:26:14,698: INFO: 1557249241: Retrieved 0 records from intervals for session 9689]
# [2025-07-02 18:26:15,200: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9689]
# [2025-07-02 18:26:15,415: INFO: 1829873344: Successfully retrieved 12 records from team_radio]
# [2025-07-02 18:26:15,416: INFO: 1557249241: Retrieved 12 records from team_radio for session 9689]
# [2025-07-02 18:26:15,921: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9689]
# [2025-07-02 18:26:16,137: INFO: 1829873344: Successfully retrieved 53 records from race_control]
# [2025-07-02 18:26:16,138: INFO: 1557249241: Retrieved 53 records from race_control for session 9689]
# [2025-07-02 18:26:16,642: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9689]
# [2025-07-02 18:26:16,843: INFO: 1829873344: Successfully retrieved 75 records from weather]
# [2025-07-02 18:26:16,844: INFO: 1557249241: Retrieved 75 records from weather for session 9689]
# [2025-07-02 18:26:16,845: INFO: 1557249241: Ingesting data for session: Race]
# [2025-07-02 18:26:17,348: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9693]
# [2025-07-02 18:26:17,539: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:17,541: INFO: 1557249241: Retrieved 0 records from sessions for session 9693]
# [2025-07-02 18:26:18,041: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9693]
# [2025-07-02 18:26:18,264: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:18,265: INFO: 1557249241: Retrieved 20 records from drivers for session 9693]
# [2025-07-02 18:26:18,769: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9693]
# [2025-07-02 18:26:19,992: INFO: 1829873344: Successfully retrieved 927 records from laps]
# [2025-07-02 18:26:19,993: INFO: 1557249241: Retrieved 927 records from laps for session 9693]
# [2025-07-02 18:26:19,993: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:19,993: INFO: 1557249241: Retrieved 0 records from car_data for session 9693]
# [2025-07-02 18:26:20,495: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9693]
# [2025-07-02 18:26:20,771: INFO: 1829873344: Successfully retrieved 82 records from pit]
# [2025-07-02 18:26:20,773: INFO: 1557249241: Retrieved 82 records from pit for session 9693]
# [2025-07-02 18:26:21,275: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9693]
# [2025-07-02 18:26:21,514: INFO: 1829873344: Successfully retrieved 106 records from stints]
# [2025-07-02 18:26:21,515: INFO: 1557249241: Retrieved 106 records from stints for session 9693]
# [2025-07-02 18:26:22,019: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9693]
# [2025-07-02 18:26:22,256: INFO: 1829873344: Successfully retrieved 240 records from position]
# [2025-07-02 18:26:22,257: INFO: 1557249241: Retrieved 240 records from position for session 9693]
# [2025-07-02 18:26:22,760: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9693]
# [2025-07-02 18:26:24,565: INFO: 1829873344: Successfully retrieved 18965 records from intervals]
# [2025-07-02 18:26:24,566: INFO: 1557249241: Retrieved 18965 records from intervals for session 9693]
# [2025-07-02 18:26:25,061: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9693]
# [2025-07-02 18:26:25,268: INFO: 1829873344: Successfully retrieved 20 records from team_radio]
# [2025-07-02 18:26:25,268: INFO: 1557249241: Retrieved 20 records from team_radio for session 9693]
# [2025-07-02 18:26:25,773: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9693]
# [2025-07-02 18:26:26,016: INFO: 1829873344: Successfully retrieved 113 records from race_control]
# [2025-07-02 18:26:26,016: INFO: 1557249241: Retrieved 113 records from race_control for session 9693]
# [2025-07-02 18:26:26,521: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9693]
# [2025-07-02 18:26:26,736: INFO: 1829873344: Successfully retrieved 178 records from weather]
# [2025-07-02 18:26:26,736: INFO: 1557249241: Retrieved 178 records from weather for session 9693]
# [2025-07-02 18:26:26,742: INFO: 1957311327: Successfully connected to PostgreSQL database]
# [2025-07-02 18:26:27,239: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1254]
# [2025-07-02 18:26:27,439: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:26:27,887: INFO: 1957311327: Successfully inserted meeting 1254 data with optimized schema]
# ✅ Australian Grand Prix data successfully ingested!
#
# === Ingesting Chinese Grand Prix (Key: 1255) ===
# [2025-07-02 18:26:27,888: INFO: 1557249241: Starting data ingestion for meeting: 1255]
# [2025-07-02 18:26:27,941: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:26:28,142: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# [2025-07-02 18:26:28,647: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1255]
# [2025-07-02 18:26:28,835: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:26:28,835: INFO: 1557249241: Found 5 sessions for meeting 1255]
# [2025-07-02 18:26:28,835: INFO: 1557249241: Ingesting data for session: Practice 1]
# [2025-07-02 18:26:29,338: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9988]
# [2025-07-02 18:26:29,530: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:29,531: INFO: 1557249241: Retrieved 0 records from sessions for session 9988]
# [2025-07-02 18:26:30,035: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9988]
# [2025-07-02 18:26:30,238: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:30,238: INFO: 1557249241: Retrieved 20 records from drivers for session 9988]
# [2025-07-02 18:26:30,741: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9988]
# [2025-07-02 18:26:31,479: INFO: 1829873344: Successfully retrieved 459 records from laps]
# [2025-07-02 18:26:31,479: INFO: 1557249241: Retrieved 459 records from laps for session 9988]
# [2025-07-02 18:26:31,480: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:31,480: INFO: 1557249241: Retrieved 0 records from car_data for session 9988]
# [2025-07-02 18:26:31,979: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9988]
# [2025-07-02 18:26:32,177: INFO: 1829873344: Successfully retrieved 74 records from pit]
# [2025-07-02 18:26:32,177: INFO: 1557249241: Retrieved 74 records from pit for session 9988]
# [2025-07-02 18:26:32,682: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9988]
# [2025-07-02 18:26:33,052: INFO: 1829873344: Successfully retrieved 74 records from stints]
# [2025-07-02 18:26:33,052: INFO: 1557249241: Retrieved 74 records from stints for session 9988]
# [2025-07-02 18:26:33,554: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9988]
# [2025-07-02 18:26:33,922: INFO: 1829873344: Successfully retrieved 777 records from position]
# [2025-07-02 18:26:33,923: INFO: 1557249241: Retrieved 777 records from position for session 9988]
# [2025-07-02 18:26:34,426: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9988]
# [2025-07-02 18:26:34,615: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:26:34,615: INFO: 1557249241: Retrieved 0 records from intervals for session 9988]
# [2025-07-02 18:26:35,120: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9988]
# [2025-07-02 18:26:35,330: INFO: 1829873344: Successfully retrieved 10 records from team_radio]
# [2025-07-02 18:26:35,331: INFO: 1557249241: Retrieved 10 records from team_radio for session 9988]
# [2025-07-02 18:26:35,835: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9988]
# [2025-07-02 18:26:36,053: INFO: 1829873344: Successfully retrieved 11 records from race_control]
# [2025-07-02 18:26:36,054: INFO: 1557249241: Retrieved 11 records from race_control for session 9988]
# [2025-07-02 18:26:36,554: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9988]
# [2025-07-02 18:26:36,754: INFO: 1829873344: Successfully retrieved 82 records from weather]
# [2025-07-02 18:26:36,755: INFO: 1557249241: Retrieved 82 records from weather for session 9988]
# [2025-07-02 18:26:36,755: INFO: 1557249241: Skipping session: Sprint Qualifying]
# [2025-07-02 18:26:36,756: INFO: 1557249241: Ingesting data for session: Sprint]
# [2025-07-02 18:26:37,255: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9993]
# [2025-07-02 18:26:37,454: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:37,456: INFO: 1557249241: Retrieved 0 records from sessions for session 9993]
# [2025-07-02 18:26:37,959: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9993]
# [2025-07-02 18:26:38,179: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:38,181: INFO: 1557249241: Retrieved 20 records from drivers for session 9993]
# [2025-07-02 18:26:38,684: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9993]
# [2025-07-02 18:26:39,446: INFO: 1829873344: Successfully retrieved 380 records from laps]
# [2025-07-02 18:26:39,448: INFO: 1557249241: Retrieved 380 records from laps for session 9993]
# [2025-07-02 18:26:39,449: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:39,450: INFO: 1557249241: Retrieved 0 records from car_data for session 9993]
# [2025-07-02 18:26:39,948: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9993]
# [2025-07-02 18:26:40,136: INFO: 1829873344: Successfully retrieved 1 records from pit]
# [2025-07-02 18:26:40,138: INFO: 1557249241: Retrieved 1 records from pit for session 9993]
# [2025-07-02 18:26:40,636: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9993]
# [2025-07-02 18:26:41,041: INFO: 1829873344: Successfully retrieved 21 records from stints]
# [2025-07-02 18:26:41,041: INFO: 1557249241: Retrieved 21 records from stints for session 9993]
# [2025-07-02 18:26:41,546: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9993]
# [2025-07-02 18:26:41,750: INFO: 1829873344: Successfully retrieved 88 records from position]
# [2025-07-02 18:26:41,751: INFO: 1557249241: Retrieved 88 records from position for session 9993]
# [2025-07-02 18:26:42,255: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9993]
# [2025-07-02 18:26:43,100: INFO: 1829873344: Successfully retrieved 7957 records from intervals]
# [2025-07-02 18:26:43,100: INFO: 1557249241: Retrieved 7957 records from intervals for session 9993]
# [2025-07-02 18:26:43,595: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9993]
# [2025-07-02 18:26:43,805: INFO: 1829873344: Successfully retrieved 9 records from team_radio]
# [2025-07-02 18:26:43,807: INFO: 1557249241: Retrieved 9 records from team_radio for session 9993]
# [2025-07-02 18:26:44,309: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9993]
# [2025-07-02 18:26:44,530: INFO: 1829873344: Successfully retrieved 27 records from race_control]
# [2025-07-02 18:26:44,531: INFO: 1557249241: Retrieved 27 records from race_control for session 9993]
# [2025-07-02 18:26:45,035: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9993]
# [2025-07-02 18:26:45,262: INFO: 1829873344: Successfully retrieved 84 records from weather]
# [2025-07-02 18:26:45,264: INFO: 1557249241: Retrieved 84 records from weather for session 9993]
# [2025-07-02 18:26:45,265: INFO: 1557249241: Ingesting data for session: Qualifying]
# [2025-07-02 18:26:45,766: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9994]
# [2025-07-02 18:26:45,963: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:45,963: INFO: 1557249241: Retrieved 0 records from sessions for session 9994]
# [2025-07-02 18:26:46,467: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9994]
# [2025-07-02 18:26:46,669: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:46,670: INFO: 1557249241: Retrieved 20 records from drivers for session 9994]
# [2025-07-02 18:26:47,174: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9994]
# [2025-07-02 18:26:47,958: INFO: 1829873344: Successfully retrieved 314 records from laps]
# [2025-07-02 18:26:47,959: INFO: 1557249241: Retrieved 314 records from laps for session 9994]
# [2025-07-02 18:26:47,960: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:47,961: INFO: 1557249241: Retrieved 0 records from car_data for session 9994]
# [2025-07-02 18:26:48,457: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9994]
# [2025-07-02 18:26:48,672: INFO: 1829873344: Successfully retrieved 101 records from pit]
# [2025-07-02 18:26:48,673: INFO: 1557249241: Retrieved 101 records from pit for session 9994]
# [2025-07-02 18:26:49,174: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9994]
# [2025-07-02 18:26:49,433: INFO: 1829873344: Successfully retrieved 101 records from stints]
# [2025-07-02 18:26:49,434: INFO: 1557249241: Retrieved 101 records from stints for session 9994]
# [2025-07-02 18:26:49,938: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9994]
# [2025-07-02 18:26:50,387: INFO: 1829873344: Successfully retrieved 1430 records from position]
# [2025-07-02 18:26:50,389: INFO: 1557249241: Retrieved 1430 records from position for session 9994]
# [2025-07-02 18:26:50,886: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9994]
# [2025-07-02 18:26:51,081: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:26:51,084: INFO: 1557249241: Retrieved 0 records from intervals for session 9994]
# [2025-07-02 18:26:51,586: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9994]
# [2025-07-02 18:26:51,796: INFO: 1829873344: Successfully retrieved 11 records from team_radio]
# [2025-07-02 18:26:51,797: INFO: 1557249241: Retrieved 11 records from team_radio for session 9994]
# [2025-07-02 18:26:52,301: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9994]
# [2025-07-02 18:26:52,541: INFO: 1829873344: Successfully retrieved 117 records from race_control]
# [2025-07-02 18:26:52,542: INFO: 1557249241: Retrieved 117 records from race_control for session 9994]
# [2025-07-02 18:26:53,046: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9994]
# [2025-07-02 18:26:53,252: INFO: 1829873344: Successfully retrieved 77 records from weather]
# [2025-07-02 18:26:53,254: INFO: 1557249241: Retrieved 77 records from weather for session 9994]
# [2025-07-02 18:26:53,256: INFO: 1557249241: Ingesting data for session: Race]
# [2025-07-02 18:26:53,757: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9998]
# [2025-07-02 18:26:53,959: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:26:53,961: INFO: 1557249241: Retrieved 0 records from sessions for session 9998]
# [2025-07-02 18:26:54,464: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9998]
# [2025-07-02 18:26:54,665: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:26:54,666: INFO: 1557249241: Retrieved 20 records from drivers for session 9998]
# [2025-07-02 18:26:55,170: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9998]
# [2025-07-02 18:26:55,920: INFO: 1829873344: Successfully retrieved 1065 records from laps]
# [2025-07-02 18:26:55,921: INFO: 1557249241: Retrieved 1065 records from laps for session 9998]
# [2025-07-02 18:26:55,921: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:26:55,922: INFO: 1557249241: Retrieved 0 records from car_data for session 9998]
# [2025-07-02 18:26:56,420: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9998]
# [2025-07-02 18:26:56,615: INFO: 1829873344: Successfully retrieved 25 records from pit]
# [2025-07-02 18:26:56,616: INFO: 1557249241: Retrieved 25 records from pit for session 9998]
# [2025-07-02 18:26:57,120: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9998]
# [2025-07-02 18:26:57,425: INFO: 1829873344: Successfully retrieved 45 records from stints]
# [2025-07-02 18:26:57,427: INFO: 1557249241: Retrieved 45 records from stints for session 9998]
# [2025-07-02 18:26:57,930: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9998]
# [2025-07-02 18:26:58,340: INFO: 1829873344: Successfully retrieved 386 records from position]
# [2025-07-02 18:26:58,341: INFO: 1557249241: Retrieved 386 records from position for session 9998]
# [2025-07-02 18:26:58,845: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9998]
# [2025-07-02 18:27:00,926: INFO: 1829873344: Successfully retrieved 22207 records from intervals]
# [2025-07-02 18:27:00,926: INFO: 1557249241: Retrieved 22207 records from intervals for session 9998]
# [2025-07-02 18:27:01,410: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9998]
# [2025-07-02 18:27:01,626: INFO: 1829873344: Successfully retrieved 44 records from team_radio]
# [2025-07-02 18:27:01,627: INFO: 1557249241: Retrieved 44 records from team_radio for session 9998]
# [2025-07-02 18:27:02,131: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9998]
# [2025-07-02 18:27:02,357: INFO: 1829873344: Successfully retrieved 56 records from race_control]
# [2025-07-02 18:27:02,358: INFO: 1557249241: Retrieved 56 records from race_control for session 9998]
# [2025-07-02 18:27:02,861: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9998]
# [2025-07-02 18:27:03,091: INFO: 1829873344: Successfully retrieved 154 records from weather]
# [2025-07-02 18:27:03,092: INFO: 1557249241: Retrieved 154 records from weather for session 9998]
# [2025-07-02 18:27:03,112: INFO: 1957311327: Successfully connected to PostgreSQL database]
# [2025-07-02 18:27:03,595: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1255]
# [2025-07-02 18:27:03,789: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:27:04,169: INFO: 1957311327: Successfully inserted meeting 1255 data with optimized schema]
# ✅ Chinese Grand Prix data successfully ingested!
#
# === Ingesting Japanese Grand Prix (Key: 1256) ===
# [2025-07-02 18:27:04,170: INFO: 1557249241: Starting data ingestion for meeting: 1256]
# [2025-07-02 18:27:04,294: INFO: 1829873344: Making request to: https://api.openf1.org/v1/meetings]
# [2025-07-02 18:27:04,509: INFO: 1829873344: Successfully retrieved 60 records from meetings]
# [2025-07-02 18:27:05,013: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1256]
# [2025-07-02 18:27:05,205: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:27:05,205: INFO: 1557249241: Found 5 sessions for meeting 1256]
# [2025-07-02 18:27:05,206: INFO: 1557249241: Ingesting data for session: Practice 1]
# [2025-07-02 18:27:05,710: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9999]
# [2025-07-02 18:27:05,906: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:27:05,907: INFO: 1557249241: Retrieved 0 records from sessions for session 9999]
# [2025-07-02 18:27:06,411: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9999]
# [2025-07-02 18:27:06,606: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:27:06,607: INFO: 1557249241: Retrieved 20 records from drivers for session 9999]
# [2025-07-02 18:27:07,111: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9999]
# [2025-07-02 18:27:07,796: INFO: 1829873344: Successfully retrieved 497 records from laps]
# [2025-07-02 18:27:07,796: INFO: 1557249241: Retrieved 497 records from laps for session 9999]
# [2025-07-02 18:27:07,796: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:27:07,797: INFO: 1557249241: Retrieved 0 records from car_data for session 9999]
# [2025-07-02 18:27:08,298: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9999]
# [2025-07-02 18:27:08,507: INFO: 1829873344: Successfully retrieved 87 records from pit]
# [2025-07-02 18:27:08,507: INFO: 1557249241: Retrieved 87 records from pit for session 9999]
# [2025-07-02 18:27:09,012: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9999]
# [2025-07-02 18:27:09,253: INFO: 1829873344: Successfully retrieved 87 records from stints]
# [2025-07-02 18:27:09,254: INFO: 1557249241: Retrieved 87 records from stints for session 9999]
# [2025-07-02 18:27:09,758: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9999]
# [2025-07-02 18:27:10,147: INFO: 1829873344: Successfully retrieved 714 records from position]
# [2025-07-02 18:27:10,149: INFO: 1557249241: Retrieved 714 records from position for session 9999]
# [2025-07-02 18:27:10,651: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9999]
# [2025-07-02 18:27:10,866: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:27:10,868: INFO: 1557249241: Retrieved 0 records from intervals for session 9999]
# [2025-07-02 18:27:11,367: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9999]
# [2025-07-02 18:27:11,573: INFO: 1829873344: Successfully retrieved 9 records from team_radio]
# [2025-07-02 18:27:11,574: INFO: 1557249241: Retrieved 9 records from team_radio for session 9999]
# [2025-07-02 18:27:12,079: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9999]
# [2025-07-02 18:27:12,287: INFO: 1829873344: Successfully retrieved 4 records from race_control]
# [2025-07-02 18:27:12,289: INFO: 1557249241: Retrieved 4 records from race_control for session 9999]
# [2025-07-02 18:27:12,788: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9999]
# [2025-07-02 18:27:13,014: INFO: 1829873344: Successfully retrieved 81 records from weather]
# [2025-07-02 18:27:13,017: INFO: 1557249241: Retrieved 81 records from weather for session 9999]
# [2025-07-02 18:27:13,018: INFO: 1557249241: Ingesting data for session: Practice 2]
# [2025-07-02 18:27:13,519: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=10000]
# [2025-07-02 18:27:13,757: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:27:13,758: INFO: 1557249241: Retrieved 0 records from sessions for session 10000]
# [2025-07-02 18:27:14,260: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=10000]
# [2025-07-02 18:27:14,478: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:27:14,479: INFO: 1557249241: Retrieved 20 records from drivers for session 10000]
# [2025-07-02 18:27:14,983: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=10000]
# [2025-07-02 18:27:15,623: INFO: 1829873344: Successfully retrieved 202 records from laps]
# [2025-07-02 18:27:15,624: INFO: 1557249241: Retrieved 202 records from laps for session 10000]
# [2025-07-02 18:27:15,625: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:27:15,625: INFO: 1557249241: Retrieved 0 records from car_data for session 10000]
# [2025-07-02 18:27:16,127: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=10000]
# [2025-07-02 18:27:16,323: INFO: 1829873344: Successfully retrieved 76 records from pit]
# [2025-07-02 18:27:16,324: INFO: 1557249241: Retrieved 76 records from pit for session 10000]
# [2025-07-02 18:27:16,828: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=10000]
# [2025-07-02 18:27:17,095: INFO: 1829873344: Successfully retrieved 76 records from stints]
# [2025-07-02 18:27:17,097: INFO: 1557249241: Retrieved 76 records from stints for session 10000]
# [2025-07-02 18:27:17,595: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=10000]
# [2025-07-02 18:27:17,827: INFO: 1829873344: Successfully retrieved 495 records from position]
# [2025-07-02 18:27:17,828: INFO: 1557249241: Retrieved 495 records from position for session 10000]
# [2025-07-02 18:27:18,332: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=10000]
# [2025-07-02 18:27:18,527: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:27:18,529: INFO: 1557249241: Retrieved 0 records from intervals for session 10000]
# [2025-07-02 18:27:19,029: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=10000]
# [2025-07-02 18:27:19,239: INFO: 1829873344: Successfully retrieved 2 records from team_radio]
# [2025-07-02 18:27:19,240: INFO: 1557249241: Retrieved 2 records from team_radio for session 10000]
# [2025-07-02 18:27:19,741: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=10000]
# [2025-07-02 18:27:19,964: INFO: 1829873344: Successfully retrieved 31 records from race_control]
# [2025-07-02 18:27:19,965: INFO: 1557249241: Retrieved 31 records from race_control for session 10000]
# [2025-07-02 18:27:20,469: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=10000]
# [2025-07-02 18:27:20,697: INFO: 1829873344: Successfully retrieved 75 records from weather]
# [2025-07-02 18:27:20,698: INFO: 1557249241: Retrieved 75 records from weather for session 10000]
# [2025-07-02 18:27:20,699: INFO: 1557249241: Ingesting data for session: Practice 3]
# [2025-07-02 18:27:21,202: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=10001]
# [2025-07-02 18:27:21,389: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:27:21,390: INFO: 1557249241: Retrieved 0 records from sessions for session 10001]
# [2025-07-02 18:27:21,894: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=10001]
# [2025-07-02 18:27:22,105: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:27:22,106: INFO: 1557249241: Retrieved 20 records from drivers for session 10001]
# [2025-07-02 18:27:22,610: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=10001]
# [2025-07-02 18:27:23,293: INFO: 1829873344: Successfully retrieved 327 records from laps]
# [2025-07-02 18:27:23,294: INFO: 1557249241: Retrieved 327 records from laps for session 10001]
# [2025-07-02 18:27:23,294: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:27:23,295: INFO: 1557249241: Retrieved 0 records from car_data for session 10001]
# [2025-07-02 18:27:23,795: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=10001]
# [2025-07-02 18:27:23,991: INFO: 1829873344: Successfully retrieved 84 records from pit]
# [2025-07-02 18:27:23,992: INFO: 1557249241: Retrieved 84 records from pit for session 10001]
# [2025-07-02 18:27:24,492: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=10001]
# [2025-07-02 18:27:24,734: INFO: 1829873344: Successfully retrieved 84 records from stints]
# [2025-07-02 18:27:24,735: INFO: 1557249241: Retrieved 84 records from stints for session 10001]
# [2025-07-02 18:27:25,239: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=10001]
# [2025-07-02 18:27:25,552: INFO: 1829873344: Successfully retrieved 551 records from position]
# [2025-07-02 18:27:25,553: INFO: 1557249241: Retrieved 551 records from position for session 10001]
# [2025-07-02 18:27:26,052: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=10001]
# [2025-07-02 18:27:26,236: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:27:26,237: INFO: 1557249241: Retrieved 0 records from intervals for session 10001]
# [2025-07-02 18:27:26,740: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=10001]
# [2025-07-02 18:27:26,959: INFO: 1829873344: Successfully retrieved 5 records from team_radio]
# [2025-07-02 18:27:26,961: INFO: 1557249241: Retrieved 5 records from team_radio for session 10001]
# [2025-07-02 18:27:27,464: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=10001]
# [2025-07-02 18:27:27,675: INFO: 1829873344: Successfully retrieved 15 records from race_control]
# [2025-07-02 18:27:27,677: INFO: 1557249241: Retrieved 15 records from race_control for session 10001]
# [2025-07-02 18:27:28,180: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=10001]
# [2025-07-02 18:27:28,394: INFO: 1829873344: Successfully retrieved 75 records from weather]
# [2025-07-02 18:27:28,395: INFO: 1557249241: Retrieved 75 records from weather for session 10001]
# [2025-07-02 18:27:28,395: INFO: 1557249241: Ingesting data for session: Qualifying]
# [2025-07-02 18:27:28,899: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=10002]
# [2025-07-02 18:27:29,106: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:27:29,106: INFO: 1557249241: Retrieved 0 records from sessions for session 10002]
# [2025-07-02 18:27:29,610: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=10002]
# [2025-07-02 18:27:29,811: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:27:29,812: INFO: 1557249241: Retrieved 20 records from drivers for session 10002]
# [2025-07-02 18:27:30,316: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=10002]
# [2025-07-02 18:27:30,966: INFO: 1829873344: Successfully retrieved 291 records from laps]
# [2025-07-02 18:27:30,966: INFO: 1557249241: Retrieved 291 records from laps for session 10002]
# [2025-07-02 18:27:30,967: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:27:30,968: INFO: 1557249241: Retrieved 0 records from car_data for session 10002]
# [2025-07-02 18:27:31,469: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=10002]
# [2025-07-02 18:27:31,692: INFO: 1829873344: Successfully retrieved 96 records from pit]
# [2025-07-02 18:27:31,693: INFO: 1557249241: Retrieved 96 records from pit for session 10002]
# [2025-07-02 18:27:32,197: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=10002]
# [2025-07-02 18:27:32,559: INFO: 1829873344: Successfully retrieved 96 records from stints]
# [2025-07-02 18:27:32,560: INFO: 1557249241: Retrieved 96 records from stints for session 10002]
# [2025-07-02 18:27:33,064: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=10002]
# [2025-07-02 18:27:33,514: INFO: 1829873344: Successfully retrieved 1304 records from position]
# [2025-07-02 18:27:33,515: INFO: 1557249241: Retrieved 1304 records from position for session 10002]
# [2025-07-02 18:27:34,014: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=10002]
# [2025-07-02 18:27:34,209: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:27:34,210: INFO: 1557249241: Retrieved 0 records from intervals for session 10002]
# [2025-07-02 18:27:34,712: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=10002]
# [2025-07-02 18:27:34,921: INFO: 1829873344: Successfully retrieved 11 records from team_radio]
# [2025-07-02 18:27:34,922: INFO: 1557249241: Retrieved 11 records from team_radio for session 10002]
# [2025-07-02 18:27:35,426: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=10002]
# [2025-07-02 18:27:35,658: INFO: 1829873344: Successfully retrieved 28 records from race_control]
# [2025-07-02 18:27:35,659: INFO: 1557249241: Retrieved 28 records from race_control for session 10002]
# [2025-07-02 18:27:36,162: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=10002]
# [2025-07-02 18:27:36,376: INFO: 1829873344: Successfully retrieved 85 records from weather]
# [2025-07-02 18:27:36,377: INFO: 1557249241: Retrieved 85 records from weather for session 10002]
# ...
# [2025-07-02 18:32:49,523: INFO: 1557249241: Retrieved 0 records from car_data for session 9948]
# [2025-07-02 18:32:50,029: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9948]
# [2025-07-02 18:32:50,221: INFO: 1829873344: Successfully retrieved 102 records from pit]
# [2025-07-02 18:32:50,221: INFO: 1557249241: Retrieved 102 records from pit for session 9948]
# [2025-07-02 18:32:50,728: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9948]
# [2025-07-02 18:32:50,963: INFO: 1829873344: Successfully retrieved 102 records from stints]
# [2025-07-02 18:32:50,963: INFO: 1557249241: Retrieved 102 records from stints for session 9948]
# [2025-07-02 18:32:51,471: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9948]
# [2025-07-02 18:32:51,837: INFO: 1829873344: Successfully retrieved 837 records from position]
# [2025-07-02 18:32:51,838: INFO: 1557249241: Retrieved 837 records from position for session 9948]
# [2025-07-02 18:32:52,341: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9948]
# [2025-07-02 18:32:52,520: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:32:52,521: INFO: 1557249241: Retrieved 0 records from intervals for session 9948]
# [2025-07-02 18:32:53,024: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9948]
# [2025-07-02 18:32:53,235: INFO: 1829873344: Successfully retrieved 12 records from team_radio]
# [2025-07-02 18:32:53,236: INFO: 1557249241: Retrieved 12 records from team_radio for session 9948]
# [2025-07-02 18:32:53,736: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9948]
# [2025-07-02 18:32:53,939: INFO: 1829873344: Successfully retrieved 15 records from race_control]
# [2025-07-02 18:32:53,939: INFO: 1557249241: Retrieved 15 records from race_control for session 9948]
# [2025-07-02 18:32:54,446: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9948]
# [2025-07-02 18:32:54,665: INFO: 1829873344: Successfully retrieved 80 records from weather]
# [2025-07-02 18:32:54,665: INFO: 1557249241: Retrieved 80 records from weather for session 9948]
# [2025-07-02 18:32:54,666: INFO: 1557249241: Ingesting data for session: Practice 2]
# [2025-07-02 18:32:55,169: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9949]
# [2025-07-02 18:32:55,365: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:32:55,365: INFO: 1557249241: Retrieved 0 records from sessions for session 9949]
# [2025-07-02 18:32:55,875: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9949]
# [2025-07-02 18:32:56,078: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:32:56,078: INFO: 1557249241: Retrieved 20 records from drivers for session 9949]
# [2025-07-02 18:32:56,587: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9949]
# [2025-07-02 18:32:57,310: INFO: 1829873344: Successfully retrieved 664 records from laps]
# [2025-07-02 18:32:57,310: INFO: 1557249241: Retrieved 664 records from laps for session 9949]
# [2025-07-02 18:32:57,311: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:32:57,311: INFO: 1557249241: Retrieved 0 records from car_data for session 9949]
# [2025-07-02 18:32:57,818: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9949]
# [2025-07-02 18:32:58,488: INFO: 1829873344: Successfully retrieved 111 records from pit]
# [2025-07-02 18:32:58,488: INFO: 1557249241: Retrieved 111 records from pit for session 9949]
# [2025-07-02 18:32:58,995: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9949]
# [2025-07-02 18:32:59,307: INFO: 1829873344: Successfully retrieved 123 records from stints]
# [2025-07-02 18:32:59,309: INFO: 1557249241: Retrieved 123 records from stints for session 9949]
# [2025-07-02 18:32:59,817: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9949]
# [2025-07-02 18:33:00,189: INFO: 1829873344: Successfully retrieved 702 records from position]
# [2025-07-02 18:33:00,191: INFO: 1557249241: Retrieved 702 records from position for session 9949]
# [2025-07-02 18:33:00,697: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9949]
# [2025-07-02 18:33:00,893: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:33:00,895: INFO: 1557249241: Retrieved 0 records from intervals for session 9949]
# [2025-07-02 18:33:01,398: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9949]
# [2025-07-02 18:33:01,603: INFO: 1829873344: Successfully retrieved 13 records from team_radio]
# [2025-07-02 18:33:01,605: INFO: 1557249241: Retrieved 13 records from team_radio for session 9949]
# [2025-07-02 18:33:02,107: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9949]
# [2025-07-02 18:33:02,313: INFO: 1829873344: Successfully retrieved 8 records from race_control]
# [2025-07-02 18:33:02,314: INFO: 1557249241: Retrieved 8 records from race_control for session 9949]
# [2025-07-02 18:33:02,823: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9949]
# [2025-07-02 18:33:03,023: INFO: 1829873344: Successfully retrieved 79 records from weather]
# [2025-07-02 18:33:03,023: INFO: 1557249241: Retrieved 79 records from weather for session 9949]
# [2025-07-02 18:33:03,024: INFO: 1557249241: Ingesting data for session: Practice 3]
# [2025-07-02 18:33:03,527: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9950]
# [2025-07-02 18:33:03,713: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:33:03,714: INFO: 1557249241: Retrieved 0 records from sessions for session 9950]
# [2025-07-02 18:33:04,223: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9950]
# [2025-07-02 18:33:04,427: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:33:04,427: INFO: 1557249241: Retrieved 20 records from drivers for session 9950]
# [2025-07-02 18:33:04,937: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9950]
# [2025-07-02 18:33:05,898: INFO: 1829873344: Successfully retrieved 416 records from laps]
# [2025-07-02 18:33:05,900: INFO: 1557249241: Retrieved 416 records from laps for session 9950]
# [2025-07-02 18:33:05,901: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:33:05,902: INFO: 1557249241: Retrieved 0 records from car_data for session 9950]
# [2025-07-02 18:33:06,395: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9950]
# [2025-07-02 18:33:06,599: INFO: 1829873344: Successfully retrieved 106 records from pit]
# [2025-07-02 18:33:06,601: INFO: 1557249241: Retrieved 106 records from pit for session 9950]
# [2025-07-02 18:33:07,109: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9950]
# [2025-07-02 18:33:07,357: INFO: 1829873344: Successfully retrieved 124 records from stints]
# [2025-07-02 18:33:07,358: INFO: 1557249241: Retrieved 124 records from stints for session 9950]
# [2025-07-02 18:33:07,864: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9950]
# [2025-07-02 18:33:08,264: INFO: 1829873344: Successfully retrieved 564 records from position]
# [2025-07-02 18:33:08,265: INFO: 1557249241: Retrieved 564 records from position for session 9950]
# [2025-07-02 18:33:08,728: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9950]
# [2025-07-02 18:33:08,933: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:33:08,934: INFO: 1557249241: Retrieved 0 records from intervals for session 9950]
# [2025-07-02 18:33:09,440: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9950]
# [2025-07-02 18:33:09,650: INFO: 1829873344: Successfully retrieved 6 records from team_radio]
# [2025-07-02 18:33:09,651: INFO: 1557249241: Retrieved 6 records from team_radio for session 9950]
# [2025-07-02 18:33:10,158: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9950]
# [2025-07-02 18:33:10,380: INFO: 1829873344: Successfully retrieved 32 records from race_control]
# [2025-07-02 18:33:10,382: INFO: 1557249241: Retrieved 32 records from race_control for session 9950]
# [2025-07-02 18:33:10,881: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9950]
# [2025-07-02 18:33:11,078: INFO: 1829873344: Successfully retrieved 79 records from weather]
# [2025-07-02 18:33:11,080: INFO: 1557249241: Retrieved 79 records from weather for session 9950]
# [2025-07-02 18:33:11,081: INFO: 1557249241: Ingesting data for session: Qualifying]
# [2025-07-02 18:33:11,588: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9951]
# [2025-07-02 18:33:11,777: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:33:11,778: INFO: 1557249241: Retrieved 0 records from sessions for session 9951]
# [2025-07-02 18:33:12,287: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9951]
# [2025-07-02 18:33:12,487: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:33:12,487: INFO: 1557249241: Retrieved 20 records from drivers for session 9951]
# [2025-07-02 18:33:12,997: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9951]
# [2025-07-02 18:33:13,667: INFO: 1829873344: Successfully retrieved 310 records from laps]
# [2025-07-02 18:33:13,669: INFO: 1557249241: Retrieved 310 records from laps for session 9951]
# [2025-07-02 18:33:13,671: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:33:13,671: INFO: 1557249241: Retrieved 0 records from car_data for session 9951]
# [2025-07-02 18:33:14,170: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9951]
# [2025-07-02 18:33:14,372: INFO: 1829873344: Successfully retrieved 105 records from pit]
# [2025-07-02 18:33:14,374: INFO: 1557249241: Retrieved 105 records from pit for session 9951]
# [2025-07-02 18:33:14,879: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9951]
# [2025-07-02 18:33:15,283: INFO: 1829873344: Successfully retrieved 117 records from stints]
# [2025-07-02 18:33:15,286: INFO: 1557249241: Retrieved 117 records from stints for session 9951]
# [2025-07-02 18:33:15,790: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9951]
# [2025-07-02 18:33:16,306: INFO: 1829873344: Successfully retrieved 1074 records from position]
# [2025-07-02 18:33:16,307: INFO: 1557249241: Retrieved 1074 records from position for session 9951]
# [2025-07-02 18:33:16,815: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9951]
# [2025-07-02 18:33:17,003: INFO: 1829873344: Successfully retrieved 0 records from intervals]
# [2025-07-02 18:33:17,004: INFO: 1557249241: Retrieved 0 records from intervals for session 9951]
# [2025-07-02 18:33:17,511: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9951]
# [2025-07-02 18:33:17,722: INFO: 1829873344: Successfully retrieved 10 records from team_radio]
# [2025-07-02 18:33:17,723: INFO: 1557249241: Retrieved 10 records from team_radio for session 9951]
# [2025-07-02 18:33:18,232: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9951]
# [2025-07-02 18:33:18,443: INFO: 1829873344: Successfully retrieved 56 records from race_control]
# [2025-07-02 18:33:18,445: INFO: 1557249241: Retrieved 56 records from race_control for session 9951]
# [2025-07-02 18:33:18,948: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9951]
# [2025-07-02 18:33:19,163: INFO: 1829873344: Successfully retrieved 88 records from weather]
# [2025-07-02 18:33:19,165: INFO: 1557249241: Retrieved 88 records from weather for session 9951]
# [2025-07-02 18:33:19,166: INFO: 1557249241: Ingesting data for session: Race]
# [2025-07-02 18:33:19,671: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=9955]
# [2025-07-02 18:33:19,869: INFO: 1829873344: Successfully retrieved 0 records from sessions]
# [2025-07-02 18:33:19,871: INFO: 1557249241: Retrieved 0 records from sessions for session 9955]
# [2025-07-02 18:33:20,369: INFO: 1829873344: Making request to: https://api.openf1.org/v1/drivers?session_key=9955]
# [2025-07-02 18:33:20,573: INFO: 1829873344: Successfully retrieved 20 records from drivers]
# [2025-07-02 18:33:20,575: INFO: 1557249241: Retrieved 20 records from drivers for session 9955]
# [2025-07-02 18:33:21,079: INFO: 1829873344: Making request to: https://api.openf1.org/v1/laps?session_key=9955]
# [2025-07-02 18:33:21,541: INFO: 1829873344: Successfully retrieved 1126 records from laps]
# [2025-07-02 18:33:21,542: INFO: 1557249241: Retrieved 1126 records from laps for session 9955]
# [2025-07-02 18:33:21,542: WARNING: 1557249241: Unknown endpoint: car_data]
# [2025-07-02 18:33:21,543: INFO: 1557249241: Retrieved 0 records from car_data for session 9955]
# [2025-07-02 18:33:22,042: INFO: 1829873344: Making request to: https://api.openf1.org/v1/pit?session_key=9955]
# [2025-07-02 18:33:22,228: INFO: 1829873344: Successfully retrieved 32 records from pit]
# [2025-07-02 18:33:22,230: INFO: 1557249241: Retrieved 32 records from pit for session 9955]
# [2025-07-02 18:33:22,737: INFO: 1829873344: Making request to: https://api.openf1.org/v1/stints?session_key=9955]
# [2025-07-02 18:33:22,977: INFO: 1829873344: Successfully retrieved 52 records from stints]
# [2025-07-02 18:33:22,979: INFO: 1557249241: Retrieved 52 records from stints for session 9955]
# [2025-07-02 18:33:23,478: INFO: 1829873344: Making request to: https://api.openf1.org/v1/position?session_key=9955]
# [2025-07-02 18:33:23,695: INFO: 1829873344: Successfully retrieved 428 records from position]
# [2025-07-02 18:33:23,697: INFO: 1557249241: Retrieved 428 records from position for session 9955]
# [2025-07-02 18:33:24,203: INFO: 1829873344: Making request to: https://api.openf1.org/v1/intervals?session_key=9955]
# [2025-07-02 18:33:25,341: INFO: 1829873344: Successfully retrieved 21944 records from intervals]
# [2025-07-02 18:33:25,342: INFO: 1557249241: Retrieved 21944 records from intervals for session 9955]
# [2025-07-02 18:33:25,827: INFO: 1829873344: Making request to: https://api.openf1.org/v1/team_radio?session_key=9955]
# [2025-07-02 18:33:26,041: INFO: 1829873344: Successfully retrieved 37 records from team_radio]
# [2025-07-02 18:33:26,042: INFO: 1557249241: Retrieved 37 records from team_radio for session 9955]
# [2025-07-02 18:33:26,541: INFO: 1829873344: Making request to: https://api.openf1.org/v1/race_control?session_key=9955]
# [2025-07-02 18:33:26,739: INFO: 1829873344: Successfully retrieved 117 records from race_control]
# [2025-07-02 18:33:26,739: INFO: 1557249241: Retrieved 117 records from race_control for session 9955]
# [2025-07-02 18:33:27,249: INFO: 1829873344: Making request to: https://api.openf1.org/v1/weather?session_key=9955]
# [2025-07-02 18:33:27,465: INFO: 1829873344: Successfully retrieved 161 records from weather]
# [2025-07-02 18:33:27,467: INFO: 1557249241: Retrieved 161 records from weather for session 9955]
# [2025-07-02 18:33:27,482: INFO: 1957311327: Successfully connected to PostgreSQL database]
# [2025-07-02 18:33:27,974: INFO: 1829873344: Making request to: https://api.openf1.org/v1/sessions?meeting_key=1264]
# [2025-07-02 18:33:28,185: INFO: 1829873344: Successfully retrieved 5 records from sessions]
# [2025-07-02 18:33:28,692: INFO: 1957311327: Successfully inserted meeting 1264 data with optimized schema]
# ✅ Austrian Grand Prix data successfully ingested!
#
# 🎉 All 2025 data ingestion completed!

# %%
# Add this helper function for progress tracking
def check_ingestion_progress():
    """Check what data has been ingested so far"""
    db_ingestion = DatabaseIngestion(data_ingestion_config, db_config, api_client)
    conn = db_ingestion.connect_to_db()
    cursor = conn.cursor()
    
    # Check meetings by year
    cursor.execute("""
        SELECT year, COUNT(*) as meeting_count 
        FROM meetings 
        GROUP BY year 
        ORDER BY year DESC
    """)
    
    results = cursor.fetchall()
    print("=== INGESTION PROGRESS ===")
    for year, count in results:
        print(f"  {year}: {count} meetings")
    
    cursor.close()
    conn.close()

# Run progress check
check_ingestion_progress()
# Out:
# [2025-07-02 18:33:28,699: INFO: 1957311327: Successfully connected to PostgreSQL database]
# === INGESTION PROGRESS ===
#   2025: 12 meetings

# %%
# Add this debugging cell (Updated)
def check_database_data():
    """Check what data is actually in the database"""
    # Create API client for the DatabaseIngestion
    api_client = OpenF1APIClient(data_ingestion_config)
    db_ingestion = DatabaseIngestion(data_ingestion_config, db_config, api_client)
    
    conn = db_ingestion.connect_to_db()
    cursor = conn.cursor()
    
    # Check meetings table
    cursor.execute("SELECT COUNT(*) FROM meetings")
    meetings_count = cursor.fetchone()[0]
    print(f"Meetings in database: {meetings_count}")
    
    if meetings_count > 0:
        cursor.execute("SELECT meeting_key, meeting_name, year FROM meetings")
        meetings = cursor.fetchall()
        print("Meetings found:")
        for meeting in meetings:
            print(f"  - {meeting[1]} ({meeting[2]}) - Key: {meeting[0]}")
    
    # Check sessions table
    cursor.execute("SELECT COUNT(*) FROM sessions")
    sessions_count = cursor.fetchone()[0]
    print(f"\nSessions in database: {sessions_count}")
    
    if sessions_count > 0:
        cursor.execute("SELECT session_key, session_name, session_type FROM sessions LIMIT 5")
        sessions = cursor.fetchall()
        print("Sessions found:")
        for session in sessions:
            print(f"  - {session[1]} ({session[2]}) - Key: {session[0]}")
    
    # Check other tables
    tables = ['drivers', 'laps', 'pit_stops', 'stints', 'positions','intervals', 'race_control']
    for table in tables:
        cursor.execute(f"SELECT COUNT(*) FROM {table}")
        count = cursor.fetchone()[0]
        print(f"{table.capitalize()} in database: {count}")
    
    cursor.close()
    conn.close()

# Run the check
check_database_data()
# Out:
# [2025-07-03 11:05:54,195: INFO: 1957311327: Successfully connected to PostgreSQL database]
# Meetings in database: 12
# Meetings found:
#   - Pre-Season Testing (2025) - Key: 1253
#   - Australian Grand Prix (2025) - Key: 1254
#   - Chinese Grand Prix (2025) - Key: 1255
#   - Japanese Grand Prix (2025) - Key: 1256
#   - Bahrain Grand Prix (2025) - Key: 1257
#   - Saudi Arabian Grand Prix (2025) - Key: 1258
#   - Miami Grand Prix (2025) - Key: 1259
#   - Emilia Romagna Grand Prix (2025) - Key: 1260
#   - Monaco Grand Prix (2025) - Key: 1261
#   - Spanish Grand Prix (2025) - Key: 1262
#   - Canadian Grand Prix (2025) - Key: 1263
#   - Austrian Grand Prix (2025) - Key: 1264
#
# Sessions in database: 53
# Sessions found:
#   - Practice 1 (Practice) - Key: 9686
#   - Practice 2 (Practice) - Key: 9687
#   - Practice 3 (Practice) - Key: 9688
#   - Qualifying (Qualifying) - Key: 9689
#   - Race (Race) - Key: 9693
# Drivers in database: 1059
# Laps in database: 29981
# Pit_stops in database: 4206
# Stints in database: 4522
# Positions in database: 36834
# Intervals in database: 288343
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[52], line 46
#      43     conn.close()
#      45 # Run the check
# ---> 46 check_database_data()
#
# Cell In[52], line 38, in check_database_data()
#      36 tables = ['drivers', 'laps', 'pit_stops', 'stints', 'positions','intervals', 'race_control']
#      37 for table in tables:
# ---> 38     cursor.execute(f"SELECT COUNT(*) FROM {table}")
#      39     count = cursor.fetchone()[0]
#      40     print(f"{table.capitalize()} in database: {count}")
#
# UndefinedTable: relation "race_control" does not exist
# LINE 1: SELECT COUNT(*) FROM race_control
#                              ^
